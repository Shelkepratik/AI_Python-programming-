# %% [markdown]
# ## What are strings in Python

# %%
name4=rahul
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 name4=rahul
#
# NameError: name 'rahul' is not defined

# %%
name='ganesh'

# %%
print(name)
# Out:
# ganesh

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
name1="mahesh"

# %%
print(name1)
# Out:
# mahesh

# %%
print(type(name1))
# Out:
# <class 'str'>

# %%
name2='''suresh'''

# %%
print(name2)
# Out:
# suresh

# %%
print(type(name2))
# Out:
# <class 'str'>

# %%
name3="""rajesh"""

# %%
print(name3)
# Out:
# rajesh

# %%
print(type(name3))
# Out:
# <class 'str'>

# %% [markdown]
# ## How to access entire string

# %%
str1="hello world"

# %%
print(str1)
# Out:
# hello world

# %% [markdown]
# ## Indexing

# %% [markdown]
# ### Positive Indexing

# %%
print(str1[0])
# Out:
# h

# %%
print(str1[1])
# Out:
# e

# %%
print(str1[2])
# Out:
# l

# %%
print(str1[3])
# Out:
# l

# %%
print(str1[4])
# Out:
# o

# %%
print(str1[5])

# %%
print(str1[6])
# Out:
# w

# %%
print(str1[7])
# Out:
# o

# %%
print(str1[8])
# Out:
# r

# %%
print(str1[9])
# Out:
# l

# %%
print(str1[10])
# Out:
# d

# %%
print(str1[11])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 print(str1[11])
#
# IndexError: string index out of range

# %%
str3="welcome to python programming"

# %%
str3[28]
# Out:
# 'g'

# %%
str3[29]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 str3[29]
#
# IndexError: string index out of range

# %%
str4="hello world"

# %%
print(str4)
# Out:
# hello world

# %% [markdown]
# ### Negative Indexing

# %%
print(str4[-11])
print(str4[-10])
print(str4[-9])
print(str4[-8])
print(str4[-7])
print(str4[-6])
print(str4[-5])
print(str4[-4])
print(str4[-3])
print(str4[-2])
print(str4[-1])
# Out:
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d

# %%
str5="hello world"

# %%
print(str5[0])
print(str5[-11])
# Out:
# h
# h

# %%
print(str5[10])
print(str5[-1])
# Out:
# d
# d

# %% [markdown]
# ## Slicing

# %%
str6="hello world"

# %%
print(str6)
# Out:
# hello world

# %%
print(str6[0])
# Out:
# h

# %%
print(str6[0:5])
# Out:
# hello

# %%
print(str6[0:5:1])
# Out:
# hello

# %%
print(str6[0:5:2])
# Out:
# hlo

# %%
print(str6[0:5:3])
# Out:
# hl

# %%
print(str6[6:11])
# Out:
# world

# %%
print(str6[6:8])
# Out:
# wo

# %%
print(str6[0:3])
# Out:
# hel

# %%
print(str6)
# Out:
# hello world

# %% [markdown]
# ### Slicing default values

# %%
print(str6[:5:1])
# Out:
# hello

# %%
print(str6[0:5:1])
# Out:
# hello

# %%
print(str6[6::1])
# Out:
# world

# %%
print(str6[::1])
# Out:
# hello world

# %%
print(str6[0:11:1])
# Out:
# hello world

# %%
print(str6[::])
# Out:
# hello world
