# %% [markdown]
# 1.what will be the output

# %%
count=1
while count<=4:
    print(count)
    count=count+1
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# 2.what is the output

# %%
value=2
while value<=8:
    print(value)
    value=value+2
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# 3.what will be the output

# %%
number=5
while number>=1:
    print(number)
    number=number-1
# Out:
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# 4.what will be the output

# %%
count=1
while count<=3:
    print("Phython")
    count=count+1
print("Completed")
# Out:
# Phython
# Phython
# Phython
# Completed

# %% [markdown]
# 5.what will be the output

# %%
count=1
while count<=3:
    print(count)
    count=count+1
else:
    print("loop completed")
# Out:
# 1
# 2
# 3
# loop completed

# %% [markdown]
# 6.what will bethe output

# %%
items=[5,10,15,20]
for item in items:
    print(item)
# Out:
# 5
# 10
# 15
# 20

# %% [markdown]
# 7.what will bw the output

# %%
numbers=[3,6,9]
for number in numbers:
    print(number*2)
# Out:
# 6
# 12
# 18

# %% [markdown]
# 8.what will bw the output

# %%
word="WORD"
for character in word:
    print(character)
# Out:
# W
# O
# R
# D

# %% [markdown]
# 9.what will bw the output

# %%
values=(10,"python",True)
for value in values:
    print(value)
# Out:
# 10
# python
# True

# %% [markdown]
# 10.what will be the output

# %%
for number in range(1,5):
    print(number)
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# 11.what will be the output

# %%
for number in range(2,10,2):
    print(number)
# Out:
# 2
# 4
# 6
# 8

# %% [markdown]
# 12.what will be the output

# %%
for number in range(10,4,-1):
    print(number)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5

# %% [markdown]
# 13.what will be the output

# %%
for number in range(1,8):
    if number==4:
        break
    print(number)
# Out:
# 1
# 2
# 3

# %% [markdown]
# 14.what will be the output

# %%
for number in range(1,8):
    if number==4:
        continue
    print(number)
# Out:
# 1
# 2
# 3
# 5
# 6
# 7

# %% [markdown]
# 15.what will be the output

# %%
count = 1

while count <= 5:
    if count == 3:
        break
    print(count)
    count = count + 1

print("Finished")
# Out:
# 1
# 2
# Finished

# %% [markdown]
# 16.what will be the output

# %%
for number in range(1, 6):
    if number == 3:
        continue
    print(number)

print("Finished")
# Out:
# 1
# 2
# 4
# 5
# Finished

# %% [markdown]
# 17.what will be the output

# %%
for number in range(1,4):
    print(number)
else:
    print("Loop completed")
# Out:
# 1
# 2
# 3
# Loop completed

# %% [markdown]
# 18.what will be the output

# %%
for number in range(1,6):
    if number==3:
        break
    print(number)
else:
    print("Loop completed")
# Out:
# 1
# 2

# %% [markdown]
# 19.what will be the output

# %%
for number in range(2, 11, 2):
    print(number)
# Out:
# 2
# 4
# 6
# 8
# 10

# %% [markdown]
# 20.what will bw the output

# %%
for number in range(5, 0, -1):
    if number == 2:
        continue
    print(number)
# Out:
# 5
# 4
# 3
# 1
