# %% [markdown]
# ##### Create three variables using valid Python identifiers and print their values.

# %%
name="pratik"
age=24
city="pune"

# %% [markdown]
# ##### Identify which of the following are valid and invalid identifiers:
# name=“ Rahul”
# 2name=“ Amit”
# first_name=“ John”
# first-name=“ David”
# _age=25

# %%
name="Rahul" #valid
#2name="Amit"  #invalid
first_name="john" #valid
#first-name="David" #invalid
_age=25

# %% [markdown]
# ##### Try using for,if,and classas variable names.What error do youget and why?

# %%
# for=10 #invalid
# if="om" #invalid
# classas="pratik"  #invalid

# %% [markdown]
# ##### Write a Python program to demonstrate that Python is casesensitive using A and a

# %%
A=20
a=10

# %% [markdown]
# ##### Create two variables: A=10 a=20 Print both values.What do you observe?

# %%
A=10
a=20
print(A)
print(a)
# Out:
# 10
# 20

# %% [markdown]
# ##### Check the type of the following values using type():
# 10
# 10.5
# 10+2j
# True
# “ Hello
# ”
# None

# %%
a=10
print(type(a))
b=10.5
print(type(b))
c=10+2j
print(type(c))
d=True
print(type(d))
e="Hello"
print(type(e))
f=None
print(type(f))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# <class 'bool'>
# <class 'str'>
# <class 'NoneType'>

# %% [markdown]
# ##### Write a program to demonstrate the difference between:
# True
# “ True”

# %%
a=True
b="True"
print(type(a))
print(type(b))
# Out:
# <class 'bool'>
# <class 'str'>

# %%
print("hello")
# Out:
# hello
