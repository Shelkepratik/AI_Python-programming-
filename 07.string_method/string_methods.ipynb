# %% [markdown]
# ## 1]Content test methods

# %% [markdown]
# #### 4.islower()

# %%
str1="hello"

# %%
print(str1.islower())
# Out:
# True

# %%
str2="Hello"

# %%
print(str2.islower())
# Out:
# False

# %% [markdown]
# #### 5. isupper()

# %%
str3="HELLO"

# %%
print(str3.isupper())
# Out:
# True

# %%
str4="HELLo"

# %%
print(str4.isupper())
# Out:
# False

# %% [markdown]
# #### 6. startswith( )

# %%
str5="hello world"

# %%
print(str5.startswith("hello"))
# Out:
# True

# %%
print(str5.startswith("world"))
# Out:
# False

# %% [markdown]
# #### 7.endswith()

# %%
str6="hello world"

# %%
print(str6.endswith("world"))
# Out:
# True

# %%
print(str6.endswith("hello"))
# Out:
# False

# %% [markdown]
# ## 2]search methods

# %% [markdown]
# #### 1.find( )

# %%
str7="Hello, welcome to python programming"

# %%
print(str7.find("python"))
# Out:
# 18

# %%
print(str7.find("java"))
# Out:
# -1

# %%
print(str7.find("welcome"))
# Out:
# 7

# %%
print(str7.find("to"))
# Out:
# 15

# %% [markdown]
# #### 2.replace()

# %%
str8="Hello, welcome to python programming"

# %%
str9=str8.replace("python","java")

# %%
print(str9)
# Out:
# Hello, welcome to java programming

# %% [markdown]
# ## 3] Trim whitespace methods

# %% [markdown]
# #### 1. lstrip()

# %%
str9="    Hello world    "

# %%
print(str9)
# Out:
#     Hello world

# %%
result=str9.lstrip()

# %%
print(result)
# Out:
# Hello world

# %% [markdown]
# #### 2.rstrip()

# %%
str10="    Hello world    "

# %%
print(str10)
# Out:
#     Hello world

# %%
result1=str10.rstrip()

# %%
print(result1)
# Out:
#     Hello world

# %% [markdown]
# #### 3.strip()

# %%
str11="    Hello world    "

# %%
print(str11)
# Out:
#     Hello world

# %%
result2=str11.strip()

# %%
print(result2)
# Out:
# Hello world

# %% [markdown]
# ## 4] split methods

# %% [markdown]
# #### 1. split()

# %%
str12="hello welcome to india"

# %%
print(str12)
# Out:
# hello welcome to india

# %%
words=str12.split()

# %%
print(words)
# Out:
# ['hello', 'welcome', 'to', 'india']

# %%
words1=str12.split(" ")

# %%
print(words1)
# Out:
# ['hello', 'welcome', 'to', 'india']

# %%
str12="I am learning - string - list"

# %%
result3=str12.split("-")

# %%
print(result3)
# Out:
# ['I am learning ', ' string ', ' list']

# %% [markdown]
# #### 2.partition()

# %%
str13="hello welcome to india"

# %%
result3=str13.partition("to")

# %%
print(result3)
# Out:
# ('hello welcome ', 'to', ' india')

# %%
str14="I am learning - string "

# %%
result4=str14.partition("-")

# %%
print(result4)
# Out:
# ('I am learning ', '-', ' string ')

# %%
str15="I am learning - string - python"

# %%
result5=str15.partition("-")

# %%
print(result5)
# Out:
# ('I am learning ', '-', ' string - python')
