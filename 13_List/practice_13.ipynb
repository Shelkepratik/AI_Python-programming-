# %% [markdown]
# 1.What will bw the output

# %%
data=[15,25,35,45,55]
print(data)
# Out:
# [15, 25, 35, 45, 55]

# %% [markdown]
# 2.what will be the output

# %%
data=[10,20,"python",True]
print(type(data))
# Out:
# <class 'list'>

# %% [markdown]
# 3.what will be the output.

# %%
values=[5,10,15,20,25]
print(values[0])
print(values[3])
# Out:
# 5
# 20

# %% [markdown]
# 4.what will be the output

# %%
values=[5,10,15,20,25]
print(values[-1])
print(values[-3])
# Out:
# 25
# 15

# %% [markdown]
# 5.what will be the output

# %%
items=[100,200,300,400,500]
print(items[1:4])
# Out:
# [200, 300, 400]

# %% [markdown]
# 6.What will be the output

# %%
items=[100,200,300,400,500]
print(items[0:5:2])
# Out:
# [100, 300, 500]

# %% [markdown]
# 7.What will be the output

# %%
items=[100,200,300,400,500]
print(items[1:5:2])
# Out:
# [200, 400]

# %% [markdown]
# 8.what will be the output

# %%
items=[100,200,300,400,500]
print(items[:3])
# Out:
# [100, 200, 300]

# %% [markdown]
# 9.what will be the output

# %%
items=[100,200,300,400,500]
print(items[2:])
# Out:
# [300, 400, 500]

# %% [markdown]
# 10.what will be the output

# %%
print(items[:])
# Out:
# [100, 200, 300, 400, 500]

# %% [markdown]
# 11.What will be the output

# %%
items=[2,4,6,8]
print(items*2)
# Out:
# [2, 4, 6, 8, 2, 4, 6, 8]

# %% [markdown]
# 12.What will be the output

# %%
names=["Amit","Neha","Ravi","Pooja"]
for name in names:
    print(name)
# Out:
# Amit
# Neha
# Ravi
# Pooja

# %% [markdown]
# 13.what will be the output

# %%
numbers=[3,6,9]
for number in numbers:
    print(number*2)
# Out:
# 6
# 12
# 18

# %% [markdown]
# 14.What will bw the output

# %%
numbers=[10,20,30]
index=0
while index<len(numbers):
    print(numbers[index])
    index+=1
# Out:
# 10
# 20
# 30

# %% [markdown]
# 15.What will be the output

# %%
numbers=[10,20,30,40]
for index,value in enumerate(numbers):
    print(index,value)
# Out:
# 0 10
# 1 20
# 2 30
# 3 40

# %% [markdown]
# 16.what will be the output

# %%
numbers=[10,20,30]
for index,value in enumerate(numbers,start=5):
    print(index,value)
# Out:
# 5 10
# 6 20
# 7 30

# %% [markdown]
# 17.what will be the output

# %%
data=[10,20,30,40,50]
print(len(data))
# Out:
# 5

# %% [markdown]
# 18.What will be the output

# %%
print(data[::2])
# Out:
# [10, 30, 50]

# %% [markdown]
# 19.What will bw the output

# %%
print(data[1::2])
# Out:
# [20, 40]

# %% [markdown]
# 20.What will be the output

# %%
print(data[0:4:3])
# Out:
# [10, 40]
