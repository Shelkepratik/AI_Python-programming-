# %% [markdown]
# 1.What will be the output?
# message="PyThOn"
# print(message.lower())

# %%
message="PyThOn"
print(message.lower())

# %%
message="PyThOn"
print(message.lower())
# Out:
# python

# %% [markdown]
# 2.What will be the output?
# message="hellopython"
# print(message.upper())

# %%
message="hellopython"
print(message.upper())
# Out:
# HELLOPYTHON

# %% [markdown]
# 3.What will be the output?
# text="pythonprogramming"
# print(text.capitalize())

# %%
text="pythonprogramming"
print(text.capitalize())
# Out:
# Pythonprogramming

# %% [markdown]
# 4.What will be the output?
# text="pythonprogramminglanguage"
# print(text.title())

# %%
text="pythonprograaminglanuage"
print(text.title())
# Out:
# Pythonprograaminglanuage

# %% [markdown]
# 5..What will be the output?
# text="PyThOn"
# print(text.swapcase())

# %%
text="PythOn"
print(text.swapcase())
# Out:
# pYTHoN
