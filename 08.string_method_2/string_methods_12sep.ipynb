# %% [markdown]
# ## Case Conversion Methods

# %% [markdown]
# #### 1. lower()

# %%
str1="HELLO"

# %%
print(str1)
# Out:
# HELLO

# %%
print(str1.lower())
# Out:
# hello

# %%
result1=str1.lower()

# %%
print(result1)
# Out:
# hello

# %%
str1="Python"

# %%
result1=str1.lower()

# %%
print(result1)
# Out:
# python

# %% [markdown]
# #### 2.upper()

# %%
str3="hello"

# %%
result4=str3.upper()

# %%
print(result4)
# Out:
# HELLO

# %%
str4="Python"

# %%
result5=str4.upper()

# %%
print(result5)
# Out:
# PYTHON

# %%
str6="PRASHANT@gmail.com"

# %%
result6=str6.lower()

# %%
print(result6)
# Out:
# prashant@gmail.com

# %% [markdown]
# #### 3. capitalize()

# %%
str7="hello world"

# %%
result7=str7.capitalize()

# %%
print(result7)
# Out:
# Hello world

# %%
str8="PYTHON iS EAsy"

# %%
result8=str8.capitalize()

# %%
print(result8)
# Out:
# Python is easy

# %% [markdown]
# #### 4.title()

# %%
str9="hello world"

# %%
result9=str9.title()

# %%
print(result9)
# Out:
# Hello World

# %%
str10="PYTHON iS EAsy"

# %%
result10=str10.title()

# %%
print(result10)
# Out:
# Python Is Easy

# %% [markdown]
# #### 5. swapcase()

# %%
str11="hello WORLD"

# %%
result11=str11.swapcase()

# %%
print(result11)
# Out:
# HELLO world

# %% [markdown]
# ## String is immutable data type - once we define any string we cannot do any modification in it.

# %%
str12="hello WORLD"

# %%
print(str12)
# Out:
# hello WORLD

# %%
print(id(str12))
# Out:
# 4441441136

# %%
print(str12.lower())
# Out:
# hello world

# %%
result12=str12.lower()

# %%
print(result12)
# Out:
# hello world

# %%
print(id(result12))
# Out:
# 4441456176

# %%
result12="Hi"

# %%
print(id(result12))
# Out:
# 4441527792

# %%
print(result12)
# Out:
# Hi

# %%
print(result12)
# Out:
# Hi

# %% [markdown]
# ## Type Conversion Built-in Functions

# %% [markdown]
# ## 1. str ( )

# %% [markdown]
# #### 1. converting integer into string

# %%
age=25

# %%
print(age)
# Out:
# 25

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
result13=str(age)

# %%
print(result13)
# Out:
# 25

# %%
print(type(result13))
# Out:
# <class 'str'>

# %% [markdown]
# #### 2. converting float into string

# %%
weight=65.8

# %%
print(weight)
# Out:
# 65.8

# %%
print(type(weight))
# Out:
# <class 'float'>

# %%
result14=str(weight)

# %%
print(result14)
# Out:
# 65.8

# %%
print(type(result14))
# Out:
# <class 'str'>

# %% [markdown]
# #### 3. converting complex into string

# %%
var1=2+3j

# %%
print(var1)
# Out:
# (2+3j)

# %%
print(type(var1))
# Out:
# <class 'complex'>

# %%
result15=str(var1)

# %%
print(result15)
# Out:
# (2+3j)

# %%
print(type(result15))
# Out:
# <class 'str'>

# %% [markdown]
# ### split() method

# %%
str15="hello welcome to python"

# %%
result15=str15.split()

# %%
print(result15)
# Out:
# ['hello', 'welcome', 'to', 'python']

# %% [markdown]
# ### join() method

# %%
print(result15)
# Out:
# ['hello', 'welcome', 'to', 'python']

# %%
sentence=" ".join(result15)

# %%
print(sentence)
# Out:
# hello welcome to python
