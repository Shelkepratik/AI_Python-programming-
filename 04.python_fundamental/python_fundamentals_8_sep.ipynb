# %% [markdown]
# ## Multiple variable Assignment in one line

# %%
name="ganesh"
city="mumbai"
age=25

# %%
print(name)
print(city)
print(age)
# Out:
# ganesh
# mumbai
# 25

# %%
name,city,age="mahesh","indore",30

# %%
print(name,city,age)
# Out:
# mahesh indore 30

# %%
a=10
b=10
c=10
d=10

# %%
print(a,b,c,d)
# Out:
# 10 10 10 10

# %%
a=b=c=d=20

# %%
print(a,b,c,d)
# Out:
# 20 20 20 20

# %% [markdown]
# ## Arithmetic Operators

# %% [markdown]
# ### 1. Addition (+)

# %%
a=10
print(a)
b=5
print(b)
c=a+b
print(c)
# Out:
# 10
# 5
# 15

# %%
print(10+5)
# Out:
# 15

# %%
print(c)
# Out:
# 15

# %%
print(a)
# Out:
# 10

# %%
print(b)
# Out:
# 5

# %% [markdown]
# ### 2. Subtraction

# %%
a=10
b=5
c=a-b
print(c)
# Out:
# 5

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
print(type(c))
# Out:
# <class 'int'>

# %%
print(id(a))
print(id(b))
print(id(c))
# Out:
# 4323422464
# 4323422304
# 4323422304

# %% [markdown]
# ### 3. Multiplication (*)

# %%
a=10
b=5
c=a*b
print(c)
# Out:
# 50

# %% [markdown]
# ### 4. Division (/)

# %%
a=10
b=5
c=a/b
print(c)
# Out:
# 2.0

# %%
print(type(c))
# Out:
# <class 'float'>

# %%
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### 5. Floor division (//)

# %%
a=10
b=5
c=a//b
print(c)
# Out:
# 2

# %%
print(type(c))
print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# ### 6. Modulus (%)

# %%
a=10
b=5
c=a%b
print(c)
# Out:
# 0

# %%
num1=10
num2=3
num3=num1%num2
print(num3)
# Out:
# 1

# %%
print(num1%num2)
# Out:
# 1

# %%
print(num3)
# Out:
# 1

# %%
print(num1/num2)
# Out:
# 3.3333333333333335

# %%
print(num1//num2)
# Out:
# 3

# %% [markdown]
# ### 7.Exponentiation (**)

# %%
a=5
b=2
c= a**b
print(c)
# Out:
# 25

# %%
a=5
b=3
c=a**b   #a^b=5^3=5*5*5=25*5=125
print(c)
# Out:
# 125

# %% [markdown]
# ## Operator Precedence

# %%
result=(2+3)*4
print(result)
# Out:
# 20

# %%
result1=2+3*4
print(result1)
# Out:
# 14

# %%
result2=2+3**2 # 3^2=3*3=9 , 2+9=11
print(result2)
# Out:
# 11

# %%
result3=10-2+3 # 10-2=8 8+3=11
print(result3)
# Out:
# 11
